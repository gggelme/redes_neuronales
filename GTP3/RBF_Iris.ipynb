# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
import os

sys.path.append(os.path.abspath('..'))

from algorithms.auxiliares import *

# %% [markdown]
# # Datos IRIS

# %%
ruta_data = os.path.abspath('../data')

X_train, y_train = cargar_datos_csv(os.path.join(ruta_data, 'iris81_trn.csv'))
X_test, y_test = cargar_datos_csv(os.path.join(ruta_data, 'iris81_tst.csv'))

y_train_ravel = y_train.ravel()
y_test_ravel = y_test.ravel()
